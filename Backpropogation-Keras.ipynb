# %%
### By using the Keras Libraray

# %%
import numpy as np
import pandas as pd

# %%
## After that creating our own dataset
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['CGPA','PROFILE_SCORE','LPA'])

# %%
## Now see our dataset
df.head()
# Out:
#    CGPA  PROFILE_SCORE  LPA
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
## Now the next imp part , importing the keras library
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
## Now storing object into variable
model = Sequential()
model.add(Dense(2,activation='linear', input_dim=2)) ## This is the input layer 
model.add(Dense(1,activation='linear'))
import warnings
warnings.filterwarnings('ignore')
# Out:
# D:\Anaconda\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 2)                   │               6 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[ 0.41847444, -0.4786458 ],
#         [ 1.0497307 , -0.78610337]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[ 1.2305437 ],
#         [-0.76711005]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
new_weights=[np.array([[0.1,0.1],
                     [0.1,0.1]], dtype=np.float32),
            np.array([0.,0.], dtype=np.float32),
            np.array([[0.1],[0.1]], dtype=np.float32),
            np.array([0.], dtype=np.float32)]

# %%
model.set_weights(new_weights)

# %%
model.get_weights()
# Out:
# [array([[0.1, 0.1],
#         [0.1, 0.1]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.1],
#         [0.1]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
optimizer=keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="mean_squared_error", optimizer=optimizer)

# %%
model.fit(df.iloc[:,0:-1].values, df['LPA'].values, epochs=75,verbose=1,batch_size=1)
# Out:
# Epoch 1/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 27.9075
# Epoch 2/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 27.5885
# Epoch 3/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 27.2733
# Epoch 4/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 26.9405
# Epoch 5/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 26.5886
# Epoch 6/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 26.2328
# Epoch 7/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 25.8381
# Epoch 8/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 25.4670
# Epoch 9/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 25.1054
# Epoch 10/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 24.6995
# Epoch 11/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 24.2411
# Epoch 12/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 23.8467
# Epoch 13/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 23.3938
# Epoch 14/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 22.9659
# Epoch 15/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 22.5279
# Epoch 16/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.0313
# Epoch 17/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.5901
# Epoch 18/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 21.0666
# Epoch 19/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 20.5896
# Epoch 20/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 20.0941
# Epoch 21/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 19.5832
# Epoch 22/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.0841
# Epoch 23/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 18.6087
# Epoch 24/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 18.0541
# Epoch 25/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.5660
# Epoch 26/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.0105
# Epoch 27/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.4851
# Epoch 28/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.9411
# Epoch 29/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 15.4444
# Epoch 30/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14.8900
# Epoch 31/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 14.3639
# Epoch 32/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 13.8661
# Epoch 33/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 13.3462
# Epoch 34/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12.8135
# Epoch 35/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12.3455
# Epoch 36/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.8076
# Epoch 37/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 11.3521
# Epoch 38/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 10.7941
# Epoch 39/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.3693
# Epoch 40/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.9154
# Epoch 41/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.4312
# Epoch 42/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.9780
# Epoch 43/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.5356
# Epoch 44/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1116
# Epoch 45/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7558
# Epoch 46/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.3256
# Epoch 47/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8834
# Epoch 48/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5473
# Epoch 49/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.2085
# Epoch 50/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.8949
# Epoch 51/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.4922
# Epoch 52/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2511
# Epoch 53/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9061
# Epoch 54/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.6546
# Epoch 55/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3595
# Epoch 56/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0629
# Epoch 57/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.8486
# Epoch 58/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6303
# Epoch 59/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4592
# Epoch 60/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.2382
# Epoch 61/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.0050
# Epoch 62/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.8309
# Epoch 63/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7193
# Epoch 64/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.5587
# Epoch 65/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.4016
# Epoch 66/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2895
# Epoch 67/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1310
# Epoch 68/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0158
# Epoch 69/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9422
# Epoch 70/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8609
# Epoch 71/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7708
# Epoch 72/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6944
# Epoch 73/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6020
# Epoch 74/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5592
# Epoch 75/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4909

# %%
model.get_weights()
# Out:
# [array([[0.3735835 , 0.3735835 ],
#         [0.36534044, 0.36534044]], dtype=float32),
#  array([0.27215952, 0.27215952], dtype=float32),
#  array([[0.37274757],
#         [0.37274757]], dtype=float32),
#  array([0.20448948], dtype=float32)]
